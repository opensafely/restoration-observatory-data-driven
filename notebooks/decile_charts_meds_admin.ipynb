# %% [markdown]
# # Changes occurring in primary care MEDICINES ADMINISTRATION activity during the pandemic
#
# ## Producing decile charts to show activity across all practices in TPP
#
# Jump to charts:
# - [High level codes](#highlevel)
# - [Detailed codes](#detailed)

# %%
import pyodbc
import pandas as pd
import os
from IPython.display import display, Markdown


dbconn = os.environ.get('DBCONN', None)
if dbconn is None:
    display("No SQL credentials. Check that the file 'environ.txt' is present. Refer to readme for further information")
else:
    dbconn = dbconn.strip('"')
    
# import custom functions from 'analysis' folder
import sys
sys.path.append('../lib/')
    
from functions import closing_connection, load_filter_codelists, filter_codelists, plotting_all


# global variables 
if 'OPENCoronaExport' in dbconn:
    threshold = 1 # min activity threshold in dummy data
else:
    threshold = 1000

# descriptions for ctv3 codes    
codes = pd.read_csv(os.path.join('..','data','code_dictionary.csv'))

# %%
######################### customise ################################
# Create lists of keywords and/or CTV3 concepts to filter codelist

keywords = ["medication", "medicine", "drug", "presc", "repeat", "rpt"]
concepts = []

display(Markdown(f"## Load list of common codes from csv and filter to meds-related activity only"))

end_date = "20201231"
####################################################################


highlevel, detailed = load_filter_codelists(end_date, keywords=keywords, concepts=concepts)
# Out:
# ## Load list of common codes from csv and filter to meds-related activity only
# High level codes: 15
# Detailed codes: 19

# %% [markdown]
# ### Additional manual filtering
# Customised for each topic after inspecting the results of the previous step

# %%
######################### customise ################################
# remove irrelevant items by filtering on CTV3 concepts/descriptions
concepts1 = ["Drug","Causes of injury and poisoning","Appliances+equipment"]
keywords1 = ["Supply of drugs payment admin", "Clinical trial administration (& drug)"] # low numbers
concepts2 = [] 
keywords2 = ["NHS 111 report received","OOH report","Telemedicine consultation"]
####################################################################

#highlevel = filter_codelists(highlevel, concepts=concepts1, codelist_type="High level",  eventcount=True)
highlevel = filter_codelists(highlevel, concepts=concepts1, keywords=keywords1, codelist_type="High level",  eventcount=True)

detailed = filter_codelists(detailed, concepts=concepts2, keywords=keywords2, codelist_type="Detailed",  eventcount=True) 


######################### customise ################################
# replace all detailed concepts with single topic
highlevel["concept_desc"] = "Meds admin"
detailed["concept_desc"] = "Meds admin"
####################################################################
# Out:
# High level codes: 0
# Event count: 0.0 million
# Detailed codes: 18
# Event count: 19.6 million

# %% [markdown]
# # Plotting decile charts
# ### Charts highlight the median practice for the rate of each code occurrence each month, along with the rates at each decile (10-90%)
# - NB Practice denominators (list size) and patient registrations only include current patients

# %% [markdown]
# # High level codes <a id="highlevel"></a>
# _None to show_
#
# Jump to [detailed codes](#detailed)

# %% [markdown]
# # Detailed codes <a id="detailed"></a>
# Jump back to [high-level codes](#highlevel)

# %%
N = min(len(detailed), 75) # number of charts to plot
pd.set_option('display.max_rows', 100) # display full contents table
plotting_all(detailed, codes, N, threshold, end_date, dbconn, False)
# Out:
# # ---
#  # Category: Meds admin
# Total events: 19.6 m
# ## Contents:
#     first_digits                                        Description  \
# 29         XaF8d                             Medication review done
# 60           8B3                                       Drug therapy
# 80         XaZ08         Has authorisation for medication under PSD
# 93         XaQA7  Administration of medication under patient gro...
# 245        XaVvz  Administration of medication under patient spe...
# 253        XaJKW      Patient understands why taking all medication
# 258        XaIoW               Medication review done by pharmacist
# 298        Xa2yC                          Able to manage medication
# 304        XaJKn                            Drug compliance checked
# 369        XaIfK                           Asthma medication review
# 364        XaJCO                     Medication review with patient
# 392        XaJHr          Has shown no side effects from medication
# 464        XaMhk              Dispensing review of use of medicines
# 466        XaJCN                 Medication review of medical notes
# 458        XaIVl                  Medication review without patient
# 461        XaJJx                   Indication for each drug checked
# 476        Y20a8      Medication review done by clinical pharmacist
# 473        XaF8c                              Medication review due
#
#      2020 events (mill)  2020 Patient count (mill)
# 29                 7.25                       5.12
# 60                 3.55                       1.98
# 80                 2.48                       2.06
# 93                 1.81                       1.49
# 245                0.51                       0.21
# 253                0.49                       0.43
# 258                0.48                       0.39
# 298                0.40                       0.37
# 304                0.39                       0.33
# 369                0.30                       0.27
# 364                0.30                       0.28
# 392                0.28                       0.26
# 464                0.23                       0.20
# 466                0.23                       0.18
# 458                0.23                       0.17
# 461                0.23                       0.21
# 476                0.22                       0.18
# 473                0.22                       0.16
# ## "XaF8d" - Medication review done
#  ### (Practices included: 2.5k (100.0%); 2020 patients: 5.12m; 2020 events: 7.25m)
# Feb median: 22.7 (IDR 42.2), April median: 14.6 (IDR 41.2), December median: 18.8 (IDR 43.8)
# Change in median from 2019: April -31.0% (Small drop); December -8.2%, (No change); Overall classification: **Recovered**
# ## "8B3" - Drug therapy
#  ### (Practices included: 2.5k (100.0%); 2020 patients: 1.98m; 2020 events: 3.55m)
# Feb median: 5.0 (IDR 22.4), April median: 3.1 (IDR 20.7), December median: 6.3 (IDR 31.7)
# Change in median from 2019: April -28.3% (Small drop); December 37.0%, (Increase); Overall classification: **Increase**
# Top 'child' codes represented within parent code above:
#   first_digits  2020 events (thou)           Description
# 0         8B3H              1873.9  Medication requested
# 1         8B3E               534.1  Drug compliance good
# 2        8B314               320.0     Medication review
# 3        8B316               233.0    Medication changed
# 4        8B311               226.8      Medication given
# ## "XaZ08" - Has authorisation for medication under PSD
#  ### (Practices included: 2.5k (98.9%); 2020 patients: 2.06m; 2020 events: 2.48m)
# Feb median: 0.1 (IDR 2.9), April median: 0.0 (IDR 1.1), December median: 0.3 (IDR 27.1)
# Change in median from 2019: April -100.0% (Large drop); December 55.8%, (Increase); Overall classification: **Increase**
# ## "XaQA7" - Administration of medication under patient group direction
#  ### (Practices included: 2.5k (98.3%); 2020 patients: 1.49m; 2020 events: 1.81m)
# Feb median: 0.5 (IDR 8.1), April median: 0.1 (IDR 4.9), December median: 4.3 (IDR 27.8)
# Change in median from 2019: April -2.7% (No change); December 621.4%, (Increase); Overall classification: **Increase**
# ## "XaVvz" - Administration of medication under patient specific directn
#  ### (Practices included: 2.1k (84.2%); 2020 patients: 211.9k; 2020 events: 0.51m)
# Feb median: 0.2 (IDR 5.3), April median: 0.1 (IDR 3.4), December median: 0.9 (IDR 5.7)
# Change in median from 2019: April -13.4% (No change); December 482.9%, (Increase); Overall classification: **Increase**
# ## "XaJKW" - Patient understands why taking all medication
#  ### (Practices included: 2.4k (95.1%); 2020 patients: 432.3k; 2020 events: 0.49m)
# Feb median: 0.1 (IDR 5.8), April median: 0.0 (IDR 2.6), December median: 0.4 (IDR 7.5)
# Change in median from 2019: April -100.0% (Large drop); December 422.2%, (Increase); Overall classification: **Increase**
# ## "XaIoW" - Medication review done by pharmacist
#  ### (Practices included: 2.5k (96.7%); 2020 patients: 389.2k; 2020 events: 0.48m)
# Feb median: 0.1 (IDR 4.1), April median: 0.0 (IDR 3.1), December median: 0.0 (IDR 4.3)
# Change in median from 2019: April -100.0% (Large drop); December 0.0%, (No change); Overall classification: **Recovered**
# ## "Xa2yC" - Able to manage medication
#  ### (Practices included: 2.3k (91.9%); 2020 patients: 366.4k; 2020 events: 0.4m)
# Feb median: 0.0 (IDR 4.0), April median: 0.1 (IDR 6.4), December median: 0.2 (IDR 5.8)
# Change in median from 2019: April 100% (Increase); December 100%, (Increase); Overall classification: **Increase**
# ## "XaJKn" - Drug compliance checked
#  ### (Practices included: 2.4k (95.0%); 2020 patients: 329.6k; 2020 events: 0.39m)
# Feb median: 0.4 (IDR 3.3), April median: 0.1 (IDR 2.0), December median: 0.5 (IDR 3.3)
# Change in median from 2019: April -2.8% (No change); December 58.9%, (Increase); Overall classification: **Increase**
# ## "XaIfK" - Asthma medication review
#  ### (Practices included: 2.5k (99.3%); 2020 patients: 270.3k; 2020 events: 0.3m)
# Feb median: 0.4 (IDR 3.5), April median: 0.1 (IDR 2.7), December median: 0.3 (IDR 3.1)
# Change in median from 2019: April -45.7% (Small drop); December 24.2%, (Increase); Overall classification: **Increase**
# ## "XaJCO" - Medication review with patient
#  ### (Practices included: 2.5k (99.4%); 2020 patients: 279.8k; 2020 events: 0.3m)
# Feb median: 0.3 (IDR 2.8), April median: 0.1 (IDR 1.1), December median: 0.2 (IDR 4.3)
# Change in median from 2019: April -76.8% (Large drop); December -9.4%, (No change); Overall classification: **Recovered**
# ## "XaJHr" - Has shown no side effects from medication
#  ### (Practices included: 2.3k (89.1%); 2020 patients: 256.8k; 2020 events: 0.28m)
# Feb median: 0.0 (IDR 2.4), April median: 0.0 (IDR 0.8), December median: 0.1 (IDR 5.4)
# Change in median from 2019: April 0% (No change); December 100%, (Increase); Overall classification: **Increase**
# ## "XaMhk" - Dispensing review of use of medicines
#  ### (Practices included: 2.0k (77.0%); 2020 patients: 201.0k; 2020 events: 0.23m)
# Feb median: 0.0 (IDR 4.0), April median: 0.0 (IDR 0.7), December median: 0.0 (IDR 4.7)
# Change in median from 2019: April 0% (No change); December 0%, (No change); Overall classification: **No change**
# ## "XaJCN" - Medication review of medical notes
#  ### (Practices included: 2.5k (97.2%); 2020 patients: 184.3k; 2020 events: 0.23m)
# Feb median: 0.0 (IDR 0.8), April median: 0.0 (IDR 0.8), December median: 0.0 (IDR 1.0)
# Change in median from 2019: April -100.0% (Large drop); December 0.0%, (No change); Overall classification: **Recovered**
# ## "XaIVl" - Medication review without patient
#  ### (Practices included: 2.4k (92.6%); 2020 patients: 172.4k; 2020 events: 0.23m)
# Feb median: 0.0 (IDR 0.5), April median: 0.0 (IDR 0.5), December median: 0.0 (IDR 1.2)
# Change in median from 2019: April 0% (No change); December 0%, (No change); Overall classification: **No change**
# ## "XaJJx" - Indication for each drug checked
#  ### (Practices included: 2.1k (83.3%); 2020 patients: 210.1k; 2020 events: 0.23m)
# Feb median: 0.0 (IDR 1.1), April median: 0.0 (IDR 0.5), December median: 0.1 (IDR 4.6)
# Change in median from 2019: April 0% (No change); December 100%, (Increase); Overall classification: **Increase**
# ## "Y20a8" - Medication review done by clinical pharmacist
#  ### (Practices included: 1.9k (75.1%); 2020 patients: 181.8k; 2020 events: 0.22m)
# Feb median: 0.0 (IDR 0.0), April median: 0.0 (IDR 0.1), December median: 0.6 (IDR 7.6)
# Change in median from 2019: April 0% (No change); December 100%, (Increase); Overall classification: **Increase**
# ## "XaF8c" - Medication review due
#  ### (Practices included: 2.3k (89.5%); 2020 patients: 162.5k; 2020 events: 0.22m)
# Feb median: 0.0 (IDR 0.4), April median: 0.0 (IDR 0.2), December median: 0.0 (IDR 0.9)
# Change in median from 2019: April 0% (No change); December 0%, (No change); Overall classification: **No change**
