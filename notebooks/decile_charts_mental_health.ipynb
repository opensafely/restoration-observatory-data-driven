# %% [markdown]
# # Changes occurring in primary care Mental Health activity during the pandemic
# ## Producing decile charts to show activity across all practices in TPP
#
# Jump to charts:
# - [High level codes](#highlevel)
# - [Detailed codes](#detailed)

# %%
import pyodbc
import pandas as pd
import os
from IPython.display import display, Markdown


dbconn = os.environ.get('DBCONN', None)
if dbconn is None:
    display("No SQL credentials. Check that the file 'environ.txt' is present. Refer to readme for further information")
else:
    dbconn = dbconn.strip('"')
    
# import custom functions from 'analysis' folder
import sys
sys.path.append('../lib/')
    
from functions import closing_connection, load_filter_codelists, filter_codelists, plotting_all


# global variables 
if 'OPENCoronaExport' in dbconn:
    threshold = 1 # min activity threshold in dummy data
else:
    threshold = 1000

# descriptions for ctv3 codes    
codes = pd.read_csv(os.path.join('..','data','code_dictionary.csv'))

# %%
######################### customise ################################
# Create lists of keywords and/or CTV3 concepts to filter codelist
keywords = ["mental", "learning", "dementia", "deleri", "psycho", "depress", "anxi", "cogn"]
concepts = ["Mental health disorder"]

display(Markdown(f"## Load list of common codes from csv and filter to Mental Health activity only"))

end_date = "20201130"
####################################################################


highlevel, detailed = load_filter_codelists(end_date, keywords=keywords, concepts=concepts)
# Out:
# ## Load list of common codes from csv and filter to Mental Health activity only
# High level codes: 15
# Detailed codes: 3

# %% [markdown]
# ### Additional manual filtering
# Customised for each topic after inspecting the results of the previous step

# %%
######################### customise ################################
# remove irrelevant items by filtering on CTV3 concepts/descriptions
concepts1 = []
keywords1 = ["environment"]
concepts2 = [] 
keywords2 = []
####################################################################

highlevel = filter_codelists(highlevel, concepts=concepts1, keywords=keywords1, codelist_type="High level",  eventcount=True)
detailed = filter_codelists(detailed, concepts=concepts2, keywords=keywords2, codelist_type="Detailed",  eventcount=True) 


######################### customise ################################
# replace all detailed concepts with single topic
highlevel["concept_desc"] = "Mental health"
detailed["concept_desc"] = "Mental health"
####################################################################
# Out:
# High level codes: 14
# Event count: 0.54 million
# Detailed codes: 3
# Event count: 0.68 million

# %% [markdown]
# # Plotting decile charts
# ### Charts highlight the median practice for the rate of each code occurrence each month, along with the rates at each decile (10-90%)
# - NB Practice denominators (list size) and patient registrations only include current patients

# %% [markdown]
# # High level codes <a id="highlevel"></a>
# Jump to [detailed codes](#detailed)

# %%
N = min(len(highlevel), 25) # number of charts to plot
plotting_all(highlevel, codes, N, threshold, end_date, dbconn, True)
# Out:
# # ---
#  # Category: Mental health
# Total events: 0.54 m
# ## Contents:
#     first_digits                                        Description  \
# 46            E2  Neurotic, personality and other nonpsychotic d...
# 117           Eu                [X]Mental and behavioural disorders
# 120           28  Nervous system and mental state general examin...
# 134           3A  Assessment: [mental disability] or [memory] or...
# 182           E1                              Non-organic psychoses
# 210           9H  Mental health administration (& patient "secti...
# 214            E                             Mental health disorder
# 205           8G                    Psychotherapy &/or sociotherapy
# 211           d5                     Antipsychotic depot injections
# 231           E0                        Organic psychotic condition
# 336           Ez                               Mental disorders NOS
# 354           E3                                 Mental retardation
# 271           d4                                 Antipsychotic drug
# 353           da                         Other antidepressant drugs
#
#      2020 events (mill)  2020 Patient count (mill)
# 46                 0.32                       0.25
# 117                0.06                       0.05
# 120                0.05                       0.04
# 134                0.04                       0.03
# 182                0.02                       0.01
# 210                0.01                       0.01
# 214                0.01                       0.01
# 205                0.01                       0.01
# 211                0.01                       0.00
# 231                0.01                       0.01
# 336                0.00                       0.00
# 354                0.00                       0.00
# 271                0.00                       0.00
# 353                0.00                       0.00
# ## "E2" - Neurotic, personality and other nonpsychotic disorders
#  ### (Practices included: 2.5k (100.0%); 2020 patients: 246.9k; 2020 events: 0.32m)
# Feb median: 1.2 (IDR 2.2), April median: 0.6 (IDR 1.7), November median: 0.8 (IDR 2.0)
# Change in median from 2019: April -45.5% (Small drop); November -33.6%, (Small drop); Overall classification: **Sustained drop**
# Top 'child' codes represented within parent code above:
#   first_digits  2020 events (thou)                   Description
# 0         E200               104.9              Anxiety disorder
# 1        E200z                72.8             Anxiety state NOS
# 2        E2273                27.0          Erectile dysfunction
# 3        E2002                26.8  Generalised anxiety disorder
# 4          E2B                18.3       Depressive disorder NEC
# ### Trend in top child code: E200 - Anxiety disorder
# ## "Eu" - [X]Mental and behavioural disorders
#  ### (Practices included: 2.5k (99.4%); 2020 patients: 49.3k; 2020 events: 0.06m)
# Feb median: 0.2 (IDR 0.5), April median: 0.1 (IDR 0.4), November median: 0.1 (IDR 0.4)
# Change in median from 2019: April -57.3% (Small drop); November -37.8%, (Small drop); Overall classification: **Sustained drop**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)  \
# 18        Eu41z                13.2
# 19        Eu413                 7.4
# 20         Eu00                 5.8
# 21        Eu002                 4.2
# 22         Eu20                 3.7
#
#                                           Description
# 18                   [X]Anxiety disorder, unspecified
# 19                   [X]Other mixed anxiety disorders
# 20                 [X]Dementia in Alzheimer's disease
# 21  [X]Dementia in Alzheimer's dis, atypical or mi...
# 22                                      Schizophrenia
# ### Trend in top child code: Eu41z - [X]Anxiety disorder, unspecified
# ## "28" - Nervous system and mental state general examination
#  ### (Practices included: 2.3k (90.7%); 2020 patients: 44.8k; 2020 events: 0.05m)
# Feb median: 0.0 (IDR 1.1), April median: 0.0 (IDR 0.2), November median: 0.0 (IDR 0.4)
# Change in median from 2019: April 0% (No change); November 0%, (No change); Overall classification: **No change**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)  \
# 29           28                42.6
# 30         2841                10.2
#
#                                           Description
# 29  Nervous system and mental state general examin...
# 30                                           Confused
# ## "3A" - Assessment: [mental disability] or [memory] or [dementia]
#  ### (Practices included: 2.0k (78.0%); 2020 patients: 29.2k; 2020 events: 0.04m)
# Feb median: 0.0 (IDR 0.7), April median: 0.0 (IDR 0.1), November median: 0.0 (IDR 0.6)
# Change in median from 2019: April 0% (No change); November 0%, (No change); Overall classification: **No change**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)       Description
# 31         3AB0                30.0  Normal behaviour
# ### Trend in top child code: 3AB0 - Normal behaviour
# ## "E1" - Non-organic psychoses
#  ### (Practices included: 2.5k (98.3%); 2020 patients: 14.5k; 2020 events: 0.02m)
# Feb median: 0.0 (IDR 0.4), April median: 0.0 (IDR 0.2), November median: 0.0 (IDR 0.2)
# Change in median from 2019: April 0% (No change); November 0%, (No change); Overall classification: **No change**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)                 Description
# 32         E103                 3.7      Paranoid schizophrenia
# 33        E1137                 3.3        Recurrent depression
# 34        E1005                 1.6  Schizophrenia in remission
# ### Trend in top child code: E103 - Paranoid schizophrenia
# ## "9H" - Mental health administration (& patient "sectioned")
#  ### (Practices included: 1.2k (46.9%); 2020 patients: 7.0k; 2020 events: 0.01m)
# Feb median: 0.0 (IDR 0.1), April median: 0.0 (IDR 0.1), November median: 0.0 (IDR 0.0)
# Change in median from 2019: April 0% (No change); November 0%, (No change); Overall classification: **No change**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)               Description
# 35          9HZ                10.1  Mental health admin. NOS
# ### Trend in top child code: 9HZ - Mental health admin. NOS
# ## "E" - Mental health disorder
#  ### (Practices included: 2.5k (100.0%); 2020 patients: 9.1k; 2020 events: 0.01m)
# Feb median: 1.6 (IDR 2.7), April median: 0.8 (IDR 2.0), November median: 1.0 (IDR 2.4)
# Change in median from 2019: April -42.7% (Small drop); November -33.8%, (Small drop); Overall classification: **Sustained drop**
# ## "8G" - Psychotherapy &/or sociotherapy
#  ### (Practices included: 1.8k (70.1%); 2020 patients: 7.6k; 2020 events: 0.01m)
# Feb median: 0.0 (IDR 0.2), April median: 0.0 (IDR 0.0), November median: 0.0 (IDR 0.1)
# Change in median from 2019: April 0% (No change); November 0%, (No change); Overall classification: **No change**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)                  Description
# 71         8GEZ                 4.8        Other social care NOS
# 72         8GEA                 2.5          Care from relatives
# 73         8G62                 1.4  Samaritans advisory service
# 74          8GE                 1.4                  Social care
# ### Trend in top child code: 8GEZ - Other social care NOS
# ## "d5" - Antipsychotic depot injections
#  ### (Practices included: 0.9k (33.6%); 2020 patients: 1.1k; 2020 events: 0.01m)
# Feb median: 0.0 (IDR 0.4), April median: 0.0 (IDR 0.4), November median: 0.0 (IDR 0.3)
# Change in median from 2019: April -100.0% (Large drop); November 0.0%, (No change); Overall classification: **Recovered**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)                            Description
# 75         d571                 1.6      Clopixol 200mg/1mL oily injection
# 76         d516                 1.3  Depixol Conc 100mg/1mL oily injection
# 77         d513                 1.1        Depixol 40mg/2mL oily injection
# ### Trend in top child code: d571 - Clopixol 200mg/1mL oily injection
# ## "E0" - Organic psychotic condition
#  ### (Practices included: 2.2k (86.5%); 2020 patients: 6.2k; 2020 events: 0.01m)
# Feb median: 0.0 (IDR 0.1), April median: 0.0 (IDR 0.1), November median: 0.0 (IDR 0.1)
# Change in median from 2019: April 0% (No change); November 0%, (No change); Overall classification: **No change**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)                  Description
# 78        E01y0                 3.9  Alcohol withdrawal syndrome
# 79        E030z                 1.0  Acute confusional state NOS
# ### Trend in top child code: E01y0 - Alcohol withdrawal syndrome
# ## "Ez" - Mental disorders NOS
#  ### (Practices included: 0.9k (34.7%); 2020 patients: 1.4k; 2020 events: 0.0m)
# Feb median: 0.0 (IDR 0.0), April median: 0.0 (IDR 0.0), November median: 0.0 (IDR 0.0)
# Change in median from 2019: April 0% (No change); November 0%, (No change); Overall classification: **No change**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)           Description
# 80           Ez                 1.5  Mental disorders NOS
# ## "E3" - Mental retardation
#  ### (Practices included: 0.6k (23.4%); 2020 patients: 1.1k; 2020 events: 0.0m)
# Feb median: 0.0 (IDR 0.1), April median: 0.0 (IDR 0.0), November median: 0.0 (IDR 0.0)
# Change in median from 2019: April 0% (No change); November 0%, (No change); Overall classification: **No change**
# Top 'child' codes represented within parent code above:
# Empty DataFrame
# Columns: [first_digits, 2020 events (thou), Description]
# Index: []
# ## "d4" - Antipsychotic drug
#  ### (Practices included: 0.7k (26.3%); 2020 patients: 1.6k; 2020 events: 0.0m)
# Feb median: 0.0 (IDR 0.2), April median: 0.0 (IDR 0.2), November median: 0.0 (IDR 0.2)
# Change in median from 2019: April 0% (No change); November 0%, (No change); Overall classification: **No change**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)         Description
# 81           d4                 1.7  Antipsychotic drug
# ## "da" - Other antidepressant drugs
#  ### (Practices included: 0.4k (15.2%); 2020 patients: 1.0k; 2020 events: 0.0m)
# Feb median: 0.0 (IDR 0.0), April median: 0.0 (IDR 0.0), November median: 0.0 (IDR 0.0)
# Change in median from 2019: April 0% (No change); November 0%, (No change); Overall classification: **No change**
# Top 'child' codes represented within parent code above:
# Empty DataFrame
# Columns: [first_digits, 2020 events (thou), Description]
# Index: []

# %% [markdown]
# # Detailed codes <a id="detailed"></a>
# Jump back to [high-level codes](#highlevel)

# %%
N = min(len(detailed), 75) # number of charts to plot
pd.set_option('display.max_rows', 100) # display full contents table
plotting_all(detailed, codes, N, threshold, end_date, dbconn, False)
# Out:
# # ---
#  # Category: Mental health
# Total events: 0.68 m
# ## Contents:
#     first_digits                Description  2020 events (mill)  \
# 376        XaK6f  Depression interim review                0.26
# 447          E20          Neurotic disorder                0.22
# 474        XE0re             Depressed mood                0.20
#
#      2020 Patient count (mill)
# 376                       0.20
# 447                       0.18
# 474                       0.16
# ## "XaK6f" - Depression interim review
#  ### (Practices included: 2.5k (99.9%); 2020 patients: 204.2k; 2020 events: 0.26m)
# Feb median: 0.8 (IDR 2.6), April median: 0.4 (IDR 1.7), November median: 0.4 (IDR 2.2)
# Change in median from 2019: April -59.7% (Small drop); November -61.0%, (Large drop); Overall classification: **Sustained drop**
# ## "E20" - Neurotic disorder
#  ### (Practices included: 2.5k (100.0%); 2020 patients: 176.8k; 2020 events: 0.22m)
# Feb median: 0.8 (IDR 1.7), April median: 0.5 (IDR 1.5), November median: 0.6 (IDR 1.6)
# Change in median from 2019: April -39.7% (Small drop); November -29.2%, (Small drop); Overall classification: **Sustained drop**
# Top 'child' codes represented within parent code above:
#   first_digits  2020 events (thou)                    Description
# 0         E200               104.9               Anxiety disorder
# 1        E200z                72.8              Anxiety state NOS
# 2        E2002                26.8   Generalised anxiety disorder
# 3         E203                 5.5  Obsessive-compulsive disorder
# 4        E2000                 4.7      Anxiety state unspecified
# ## "XE0re" - Depressed mood
#  ### (Practices included: 2.5k (99.9%); 2020 patients: 163.5k; 2020 events: 0.2m)
# Feb median: 0.6 (IDR 2.2), April median: 0.2 (IDR 0.9), November median: 0.5 (IDR 1.9)
# Change in median from 2019: April -64.8% (Large drop); November -26.4%, (Small drop); Overall classification: **Sustained drop**
