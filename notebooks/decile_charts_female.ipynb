# %% [markdown]
# # Changes occurring in primary care women's/reproductive health activity during the pandemic
#
# ## Producing decile charts to show activity across all practices in TPP
#
# Jump to charts:
# - [High level codes](#highlevel)
# - [Detailed codes](#detailed)

# %%
import pyodbc
import pandas as pd
import os
from IPython.display import display, Markdown

dbconn = os.environ.get('DBCONN', None)
if dbconn is None:
    display("No SQL credentials. Check that the file 'environ.txt' is present. Refer to readme for further information")
else:
    dbconn = dbconn.strip('"')

# import custom functions from 'analysis' folder
import sys
sys.path.append('../lib/')
    
from functions import closing_connection, load_filter_codelists, filter_codelists, plotting_all


# global variables 
if 'OPENCoronaExport' in dbconn:
    threshold = 1 # min activity threshold in dummy data
else:
    threshold = 1000

# descriptions for ctv3 codes    
codes = pd.read_csv(os.path.join('..','data','code_dictionary.csv'))

# %%
######################### customise ################################
keywords = ["breast", "smear", "cervical", "contracept", "uterine", "iud", "coil", 
            "cystosc", "preg", "female", "women", "matern", "vagi", "gynae", "obstet", 
            "endomet", "fibroid", "hysterect", "hysterosc", "prolaps", "incontin"] # case INsensitive
concepts = []

display(Markdown("## Load list of common codes from csv and filter to Women/reproductive health only"))

end_date = "20201231"
####################################################################


highlevel, detailed = load_filter_codelists(end_date, keywords=keywords, concepts=concepts)
# Out:
# ## Load list of common codes from csv and filter to Women/reproductive health only
# High level codes: 24
# Detailed codes: 21

# %% [markdown]
# ### Additional manual filtering
# Customised for each topic after inspecting the results of the previous step

# %%
######################### customise ################################
# remove irrelevant items by filtering on CTV3 concepts/descriptions
concepts1=["Administration","(Neoplasms) or (cancers)"]
keywords1 = ["Complications of pregnancy,childbirth or the puerperium OS",
             "Gynaecological appliances",
             "Risk factors in pregnancy",
             "CONTRACEPTIVE IMPLANT"]
concepts2 = ["Administration"]
keywords2 = ["non-obstetric"]
####################################################################

highlevel = filter_codelists(highlevel, concepts=concepts1, keywords=keywords1, codelist_type="High level",  eventcount=True)
detailed = filter_codelists(detailed, concepts=concepts2, keywords=keywords2, codelist_type="Detailed",  eventcount=True) 


######################### customise ################################
# replace all detailed concepts with single topic
highlevel["concept_desc"] = "Womens/reproductive health"
detailed["concept_desc"] = "Womens/reproductive health"
####################################################################
# Out:
# High level codes: 17
# Event count: 3.97 million
# Detailed codes: 11
# Event count: 6.72 million

# %% [markdown]
# # Plotting decile charts
# ### Charts highlight the median practice for the rate of each code occurrence each month, along with the rates at each decile (10-90%)
# - NB Practice denominators (list size) and patient registrations only include current patients

# %% [markdown]
# # High level codes <a id="highlevel"></a>
#
# Jump to [detailed codes](#detailed)

# %%
N = min(len(highlevel), 25) # number of charts to plot
plotting_all(highlevel, codes, N, threshold, end_date, dbconn, True)
# Out:
# # ---
#  # Category: Womens/reproductive health
# Total events: 3.97 m
# ## Contents:
#     first_digits                                        Description  \
# 18            61                                      Contraception
# 29            15            [Gynaecological] or [obstetric] history
# 33            64  (Child health care)(inf feed meth)(breast/oth ...
# 36            62  (Patient pregnant) or (pregnancy care [& anten...
# 56            K5               Other female genital tract disorders
# 74            27                              Obstetric examination
# 94            26  Examination: [genitourinary] or [urinary] or [...
# 102           K3                                 Disorder of breast
# 106           ga                 Progesterone - only contraceptives
# 112           7E               Upper female genital tract operation
# 121           L1                            Pregnancy complications
# 141           7F                  Obstetric procedure (& puerperal)
# 142           L0                    Pregnancy with abortive outcome
# 181           7D               Lower female genital tract operation
# 187           71            Endocrine system &/or breast operations
# 199           K4                 Female pelvic inflammatory disease
# 246           gg                                 Vaginal lubricants
#
#      2020 events (mill)  2020 Patient count (mill)
# 18                 1.25                       0.76
# 29                 0.62                       0.47
# 33                 0.57                       0.17
# 36                 0.51                       0.31
# 56                 0.28                       0.25
# 74                 0.18                       0.04
# 94                 0.12                       0.11
# 102                0.09                       0.07
# 106                0.08                       0.04
# 112                0.07                       0.06
# 121                0.06                       0.04
# 141                0.04                       0.04
# 142                0.04                       0.03
# 181                0.02                       0.01
# 187                0.02                       0.02
# 199                0.01                       0.01
# 246                0.01                       0.01
# ## "61" - Contraception
#  ### (Practices included: 2.5k (99.8%); 2020 patients: 755.9k; 2020 events: 1.25m)
# Feb median: 3.2 (IDR 7.9), April median: 1.2 (IDR 4.4), December median: 3.0 (IDR 8.2)
# Change in median from 2019: April -60.6% (Large drop); December 12.1%, (No change); Overall classification: **Recovered**
# Top 'child' codes represented within parent code above:
#   first_digits  2020 events (thou)                          Description
# 0          611               428.2         General contraceptive advice
# 1          614               196.5                   Oral contraception
# 2           61               147.2                        Contraception
# 3         6148               117.0  Progestogen only oral contraceptive
# 4         612Z                94.6         Contraception not needed NOS
# ### Trend in top child code: 611 - General contraceptive advice
# ## "15" - [Gynaecological] or [obstetric] history
#  ### (Practices included: 2.5k (99.8%); 2020 patients: 467.8k; 2020 events: 0.62m)
# Feb median: 1.7 (IDR 4.8), April median: 0.8 (IDR 2.6), December median: 1.3 (IDR 3.9)
# Change in median from 2019: April -51.3% (Small drop); December -17.2%, (Small drop); Overall classification: **Sustained drop**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)                     Description
# 28         1513               181.4  Last menstrual period -1st day
# 29         1514               172.8      Estimated date of delivery
# 30          156               116.0           Contraceptive history
# 31         151A                28.7      Duration of menstrual flow
# 32          153                28.6                         Gravida
# ### Trend in top child code: 1513 - Last menstrual period -1st day
# ## "64" - (Child health care)(inf feed meth)(breast/oth feed diff age)
#  ### (Practices included: 2.5k (99.3%); 2020 patients: 166.6k; 2020 events: 0.57m)
# Feb median: 1.1 (IDR 4.7), April median: 0.8 (IDR 4.1), December median: 1.0 (IDR 4.3)
# Change in median from 2019: April -33.0% (Small drop); December -11.8%, (No change); Overall classification: **Recovered**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)                      Description
# 52         6421                62.8            Bottle fed at 6 weeks
# 53         64D4                47.1  Child 6 week examination normal
# 54         6422                45.0            Breast fed at 6 weeks
# 55         64N3                35.9         Child examination.: hips
# 56         64N8                28.0    Child examination.: genitalia
# ### Trend in top child code: 6421 - Bottle fed at 6 weeks
# ## "62" - (Patient pregnant) or (pregnancy care [& antenatal])
#  ### (Practices included: 2.5k (99.6%); 2020 patients: 309.7k; 2020 events: 0.51m)
# Feb median: 1.4 (IDR 3.2), April median: 1.1 (IDR 2.5), December median: 1.3 (IDR 2.9)
# Change in median from 2019: April -27.0% (Small drop); December -1.7%, (No change); Overall classification: **Recovered**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)                   Description
# 90          621               303.2    Patient currently pregnant
# 91         62S7                35.3  Postnatal examination normal
# 92         62P1                22.3                    Breast fed
# 93         621Z                14.5          Patient pregnant NOS
# 94         62P9                13.7                 Infant weaned
# ### Trend in top child code: 621 - Patient currently pregnant
# ## "K5" - Other female genital tract disorders
#  ### (Practices included: 2.5k (99.8%); 2020 patients: 249.8k; 2020 events: 0.28m)
# Feb median: 0.9 (IDR 2.3), April median: 0.2 (IDR 0.8), December median: 0.7 (IDR 1.9)
# Change in median from 2019: April -72.3% (Large drop); December -5.4%, (No change); Overall classification: **Recovered**
# Top 'child' codes represented within parent code above:
#     first_digits  2020 events (thou)              Description
# 124         K590                67.0              Amenorrhoea
# 125         K594                56.2        Irregular periods
# 126        K5920                55.4              Menorrhagia
# 127         K5A1                18.0  Postmenopausal bleeding
# 128        K5A2z                11.4  Menopausal symptoms NOS
# ### Trend in top child code: K590 - Amenorrhoea
# ## "27" - Obstetric examination
#  ### (Practices included: 2.3k (89.6%); 2020 patients: 45.0k; 2020 events: 0.18m)
# Feb median: 0.0 (IDR 3.5), April median: 0.0 (IDR 1.9), December median: 0.0 (IDR 1.4)
# Change in median from 2019: April -100.0% (Large drop); December -100.0%, (Large drop); Overall classification: **Sustained drop**
# Top 'child' codes represented within parent code above:
#     first_digits  2020 events (thou)                     Description
# 145          276                79.5         O/E - fetal heart heard
# 146         2741                40.4  O/E - presenting part free-5/5
# 147         2743                13.7  O/E - partial engagement - 3/5
# 148         2742                11.9  O/E - presenting part free-4/5
# 149         2753                 9.0      O/E - fetal movements felt
# ### Trend in top child code: 276 - O/E - fetal heart heard
# ## "26" - Examination: [genitourinary] or [urinary] or [breast]
#  ### (Practices included: 2.5k (99.2%); 2020 patients: 109.5k; 2020 events: 0.12m)
# Feb median: 0.2 (IDR 1.3), April median: 0.0 (IDR 0.3), December median: 0.1 (IDR 1.0)
# Change in median from 2019: April -100.0% (Large drop); December -45.4%, (Small drop); Overall classification: **Sustained drop**
# Top 'child' codes represented within parent code above:
#     first_digits  2020 events (thou)                     Description
# 156         26A1                34.7      O/E - no vaginal discharge
# 157         2691                11.6  O/E-vaginal speculum exam. NAD
# 158          269                11.1    O/E - vaginal speculum exam.
# 159         26A2                10.8      O/E - white vag. discharge
# 160         2656                 7.7          O/E - testicles normal
# ### Trend in top child code: 26A1 - O/E - no vaginal discharge
# ## "K3" - Disorder of breast
#  ### (Practices included: 2.5k (99.4%); 2020 patients: 73.0k; 2020 events: 0.09m)
# Feb median: 0.2 (IDR 0.8), April median: 0.1 (IDR 0.5), December median: 0.2 (IDR 0.9)
# Change in median from 2019: April -57.9% (Small drop); December 17.8%, (Increase); Overall classification: **Increase**
# Top 'child' codes represented within parent code above:
#     first_digits  2020 events (thou)                Description
# 176        K3171                43.3                Breast lump
# 177         K317                31.4  Breast signs and symptoms
# 178           K3                 7.7         Disorder of breast
# 179        K3174                 1.8      Discharge from nipple
# 180        K3108                 1.4           Breast infection
# ### Trend in top child code: K3171 - Breast lump
# ## "ga" - Progesterone - only contraceptives
#  ### (Practices included: 2.4k (93.6%); 2020 patients: 44.4k; 2020 events: 0.08m)
# Feb median: 0.0 (IDR 1.3), April median: 0.0 (IDR 0.8), December median: 0.0 (IDR 0.9)
# Change in median from 2019: April -100.0% (Large drop); December -100.0%, (Large drop); Overall classification: **Sustained drop**
# Top 'child' codes represented within parent code above:
#     first_digits  2020 events (thou)                               Description
# 184         ga36                56.1  Depo-Provera 150mg/1mL prefilled syringe
# 185         ga73                 6.7          NEXPLANON 68mg subdermal implant
# 186           ga                 5.8        Progesterone - only contraceptives
# 187         ga32                 4.2          Depo-Provera 150mg/1mL injection
# 188         ga71                 1.5       Etonogestrel 68mg subdermal implant
# ### Trend in top child code: ga36 - Depo-Provera 150mg/1mL prefilled syringe
# ## "7E" - Upper female genital tract operation
#  ### (Practices included: 2.5k (99.1%); 2020 patients: 62.0k; 2020 events: 0.07m)
# Feb median: 0.2 (IDR 0.7), April median: 0.0 (IDR 0.3), December median: 0.2 (IDR 0.6)
# Change in median from 2019: April -100.0% (Large drop); December -11.5%, (No change); Overall classification: **Recovered**
# Top 'child' codes represented within parent code above:
#     first_digits  2020 events (thou)  \
# 191         7E0E                21.8
# 192        7E090                12.2
# 193        7E004                 6.8
# 194         7E02                 4.8
# 195        7E034                 4.1
#
#                                            Description
# 191                                       Hysteroscopy
# 192  Introduction of intrauterine contraceptive device
# 193         Large loop excision of transformation zone
# 194                                   Biopsy of cervix
# 195                               Colposcopy of cervix
# ### Trend in top child code: 7E0E - Hysteroscopy
# ## "L1" - Pregnancy complications
#  ### (Practices included: 2.5k (99.3%); 2020 patients: 42.7k; 2020 events: 0.06m)
# Feb median: 0.1 (IDR 0.5), April median: 0.1 (IDR 0.4), December median: 0.1 (IDR 0.5)
# Change in median from 2019: April -26.9% (Small drop); December 4.6%, (No change); Overall classification: **Recovered**
# Top 'child' codes represented within parent code above:
#     first_digits  2020 events (thou)                     Description
# 203        L1808                22.3   Gestational diabetes mellitus
# 204          L13                15.6          Hyperemesis gravidarum
# 205         L100                 6.3          Threatened miscarriage
# 206          L10                 3.4  Haemorrhage in early pregnancy
# 207         L163                 1.3           Recurrent miscarriage
# ### Trend in top child code: L1808 - Gestational diabetes mellitus
# ## "7F" - Obstetric procedure (& puerperal)
#  ### (Practices included: 2.5k (97.6%); 2020 patients: 35.6k; 2020 events: 0.04m)
# Feb median: 0.0 (IDR 0.4), April median: 0.0 (IDR 0.3), December median: 0.0 (IDR 0.3)
# Change in median from 2019: April -100.0% (Large drop); December -100.0%, (Large drop); Overall classification: **Sustained drop**
# Top 'child' codes represented within parent code above:
#     first_digits  2020 events (thou)                  Description
# 211         7F12                12.3  Elective caesarean delivery
# 212         7F19                 5.8    Normal delivery procedure
# 213        7F19z                 5.1          Normal delivery NOS
# 214        7F1B0                 4.3                   Episiotomy
# 215         7F17                 4.0              Vacuum delivery
# ### Trend in top child code: 7F12 - Elective caesarean delivery
# ## "L0" - Pregnancy with abortive outcome
#  ### (Practices included: 2.5k (99.4%); 2020 patients: 32.6k; 2020 events: 0.04m)
# Feb median: 0.1 (IDR 0.3), April median: 0.1 (IDR 0.3), December median: 0.1 (IDR 0.4)
# Change in median from 2019: April -24.1% (Small drop); December -5.7%, (No change); Overall classification: **Recovered**
# Top 'child' codes represented within parent code above:
#     first_digits  2020 events (thou)             Description
# 218          L04                17.9             Miscarriage
# 219         L042                13.0    Complete miscarriage
# 220          L03                 4.0       Ectopic pregnancy
# 221         L041                 3.8  Incomplete miscarriage
# ### Trend in top child code: L04 - Miscarriage
# ## "7D" - Lower female genital tract operation
#  ### (Practices included: 2.2k (87.9%); 2020 patients: 14.8k; 2020 events: 0.02m)
# Feb median: 0.0 (IDR 0.3), April median: 0.0 (IDR 0.0), December median: 0.0 (IDR 0.2)
# Change in median from 2019: April 0% (No change); December 0%, (No change); Overall classification: **No change**
# Top 'child' codes represented within parent code above:
#     first_digits  2020 events (thou)  \
# 222        7D1B1                15.2
# 223         7D1B                 1.7
#
#                                      Description
# 222        Insertion of ring pessary into vagina
# 223  Insertion of supporting pessary into vagina
# ### Trend in top child code: 7D1B1 - Insertion of ring pessary into vagina
# ## "71" - Endocrine system &/or breast operations
#  ### (Practices included: 2.5k (97.3%); 2020 patients: 15.2k; 2020 events: 0.02m)
# Feb median: 0.0 (IDR 0.2), April median: 0.0 (IDR 0.1), December median: 0.0 (IDR 0.2)
# Change in median from 2019: April 0% (No change); December 0%, (No change); Overall classification: **No change**
# Top 'child' codes represented within parent code above:
#     first_digits  2020 events (thou)          Description
# 224         7135                 5.1     Biopsy of breast
# 225        71102                 1.5    Hemithyroidectomy
# 226        71100                 1.3  Total thyroidectomy
# 227         7114                 1.1    Parathyroidectomy
# ### Trend in top child code: 7135 - Biopsy of breast
# ## "K4" - Female pelvic inflammatory disease
#  ### (Practices included: 2.4k (96.1%); 2020 patients: 12.5k; 2020 events: 0.01m)
# Feb median: 0.0 (IDR 0.2), April median: 0.0 (IDR 0.1), December median: 0.0 (IDR 0.2)
# Change in median from 2019: April 0% (No change); December 0%, (No change); Overall classification: **No change**
# Top 'child' codes represented within parent code above:
#     first_digits  2020 events (thou)                         Description
# 228         K422                 5.5           Cyst of Bartholin's gland
# 229         K423                 2.7        Abscess of Bartholin's gland
# 230           K4                 2.2  Female pelvic inflammatory disease
# ### Trend in top child code: K422 - Cyst of Bartholin's gland
# ## "gg" - Vaginal lubricants
#  ### (Practices included: 0.7k (27.6%); 2020 patients: 5.2k; 2020 events: 0.01m)
# Feb median: 0.0 (IDR 0.2), April median: 0.0 (IDR 0.1), December median: 0.0 (IDR 0.3)
# Change in median from 2019: April 0% (No change); December 0%, (No change); Overall classification: **No change**
# Top 'child' codes represented within parent code above:
#     first_digits  2020 events (thou)         Description
# 231           gg                 7.3  Vaginal lubricants

# %% [markdown]
# # Detailed codes <a id="detailed"></a>

# %%
N = min(len(detailed), 75) # number of charts to plot
plotting_all(detailed, codes, N, threshold, end_date, dbconn, False)
# Out:
# # ---
#  # Category: Womens/reproductive health
# Total events: 6.72 m
# ## Contents:
#     first_digits                                        Description  \
# 140        Xa8Pl                                     Cervical smear
# 150        XaKTi           Liquid based cervical cytology screening
# 182        XaKd4                             Cervical cytology test
# 192        XaPnn  Advice about long acting reversible contraception
# 194        XaXfc  UK medical eligib criteria for contraceptive u...
# 254        XE278                          Cervical smear - negative
# 282          614                                 Oral contraception
# 283          611                       General contraceptive advice
# 349        XaagX     Cervical smear - human papillomavirus negative
# 339          621                         Patient currently pregnant
# 411        X76Qu                                       Not pregnant
#
#      2020 events (mill)  2020 Patient count (mill)
# 140                1.11                       1.06
# 150                1.00                       0.93
# 182                0.84                       0.44
# 192                0.76                       0.54
# 194                0.75                       0.17
# 254                0.49                       0.48
# 282                0.43                       0.28
# 283                0.43                       0.32
# 349                0.32                       0.32
# 339                0.32                       0.22
# 411                0.27                       0.21
# ## "Xa8Pl" - Cervical smear
#  ### (Practices included: 2.5k (99.9%); 2020 patients: 1.06m; 2020 events: 1.11m)
# Feb median: 4.9 (IDR 4.0), April median: 0.2 (IDR 1.3), December median: 3.9 (IDR 3.7)
# Change in median from 2019: April -95.6% (Large drop); December 20.8%, (Increase); Overall classification: **Increase**
# ## "XaKTi" - Liquid based cervical cytology screening
#  ### (Practices included: 2.5k (99.8%); 2020 patients: 932.2k; 2020 events: 1.0m)
# Feb median: 4.4 (IDR 5.7), April median: 0.2 (IDR 1.2), December median: 3.5 (IDR 4.6)
# Change in median from 2019: April -96.8% (Large drop); December 23.8%, (Increase); Overall classification: **Increase**
# ## "XaKd4" - Cervical cytology test
#  ### (Practices included: 2.5k (98.6%); 2020 patients: 442.6k; 2020 events: 0.84m)
# Feb median: 0.1 (IDR 11.6), April median: 0.0 (IDR 0.7), December median: 0.0 (IDR 8.2)
# Change in median from 2019: April -100.0% (Large drop); December -100.0%, (Large drop); Overall classification: **Sustained drop**
# ## "XaPnn" - Advice about long acting reversible contraception
#  ### (Practices included: 2.5k (99.7%); 2020 patients: 539.4k; 2020 events: 0.76m)
# Feb median: 2.3 (IDR 5.5), April median: 0.7 (IDR 3.2), December median: 1.7 (IDR 5.1)
# Change in median from 2019: April -72.7% (Large drop); December -16.5%, (Small drop); Overall classification: **Sustained drop**
# ## "XaXfc" - UK medical eligib criteria for contraceptive use 2009 cat 1
#  ### (Practices included: 2.2k (86.3%); 2020 patients: 169.2k; 2020 events: 0.75m)
# Feb median: 0.1 (IDR 6.6), April median: 0.0 (IDR 3.5), December median: 0.3 (IDR 8.3)
# Change in median from 2019: April 0.0% (No change); December 386.2%, (Increase); Overall classification: **Increase**
# ## "XE278" - Cervical smear - negative
#  ### (Practices included: 2.5k (99.8%); 2020 patients: 480.7k; 2020 events: 0.49m)
# Feb median: 0.8 (IDR 5.1), April median: 0.3 (IDR 2.3), December median: 1.2 (IDR 5.7)
# Change in median from 2019: April -93.1% (Large drop); December 6.3%, (No change); Overall classification: **Recovered**
# ## "614" - Oral contraception
#  ### (Practices included: 2.5k (99.4%); 2020 patients: 281.7k; 2020 events: 0.43m)
# Feb median: 1.0 (IDR 3.4), April median: 0.4 (IDR 2.4), December median: 0.8 (IDR 3.3)
# Change in median from 2019: April -65.8% (Large drop); December -10.2%, (No change); Overall classification: **Recovered**
# Top 'child' codes represented within parent code above:
#   first_digits  2020 events (thou)                          Description
# 0          614               196.5                   Oral contraception
# 1         6148               117.0  Progestogen only oral contraceptive
# 2         6141                54.2           Oral contraceptive started
# 3         6144                31.5            Oral contraceptive repeat
# 4         6145                16.5       Oral contraception -no problem
# ## "611" - General contraceptive advice
#  ### (Practices included: 2.5k (99.6%); 2020 patients: 317.6k; 2020 events: 0.43m)
# Feb median: 0.6 (IDR 3.7), April median: 0.3 (IDR 1.8), December median: 0.8 (IDR 4.0)
# Change in median from 2019: April -41.8% (Small drop); December 41.9%, (Increase); Overall classification: **Increase**
# Top 'child' codes represented within parent code above:
#   first_digits  2020 events (thou)                   Description
# 9          611               428.2  General contraceptive advice
# ## "XaagX" - Cervical smear - human papillomavirus negative
#  ### (Practices included: 2.5k (96.6%); 2020 patients: 317.2k; 2020 events: 0.32m)
# Feb median: 0.3 (IDR 4.5), April median: 0.0 (IDR 0.9), December median: 0.0 (IDR 4.2)
# Change in median from 2019: April 0.0% (No change); December -72.4%, (Large drop); Overall classification: **No change**
# ## "621" - Patient currently pregnant
#  ### (Practices included: 2.5k (99.6%); 2020 patients: 217.7k; 2020 events: 0.32m)
# Feb median: 0.9 (IDR 1.9), April median: 0.7 (IDR 1.7), December median: 0.8 (IDR 1.9)
# Change in median from 2019: April -26.6% (Small drop); December -8.0%, (No change); Overall classification: **Recovered**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)                 Description
# 10          621               303.2  Patient currently pregnant
# 11         621Z                14.5        Patient pregnant NOS
# 12         6219                 2.9          Possible pregnancy
# 13         6216                 2.8          Pregnant - planned
# ## "X76Qu" - Not pregnant
#  ### (Practices included: 2.5k (96.7%); 2020 patients: 213.6k; 2020 events: 0.27m)
# Feb median: 0.3 (IDR 2.7), April median: 0.1 (IDR 1.4), December median: 0.4 (IDR 2.8)
# Change in median from 2019: April -44.1% (Small drop); December 113.7%, (Increase); Overall classification: **Increase**
