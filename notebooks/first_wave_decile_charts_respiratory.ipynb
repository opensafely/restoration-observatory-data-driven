# %% [markdown]
# # Changes occurring in primary care _Respiratory_ activity during the pandemic
# ## Producing decile charts to show activity across all practices in TPP
#
# Jump to charts:
# - [High level codes](#highlevel)
# - [Detailed codes](#detailed)

# %%
import pyodbc
import pandas as pd
import os
from IPython.display import display, Markdown


dbconn = os.environ.get('DBCONN', None)
if dbconn is None:
    display("No SQL credentials. Check that the file 'environ.txt' is present. Refer to readme for further information")
else:
    dbconn = dbconn.strip('"')
    
# import custom functions from 'analysis' folder
import sys
sys.path.append('../lib/')
    
from functions import closing_connection, load_filter_codelists, filter_codelists, plotting_all


# global variables 
if 'OPENCoronaExport' in dbconn:
    threshold = 1 # min activity threshold in dummy data
else:
    threshold = 1000

# descriptions for ctv3 codes    
codes = pd.read_csv(os.path.join('..','data','code_dictionary.csv'), usecols=["first_digits","Description"])

# %%
######################### customise ################################
# Create lists of keywords and/or CTV3 concepts to filter codelist
keywords = ["respiratory" , "asthma" , "COPD", "chronic obstructive", "inhaler"]
concepts = []

display(Markdown(f"## Load list of common codes from csv and filter to Respiratory activity only"))

end_date = "20200930"
####################################################################


highlevel, detailed = load_filter_codelists(end_date, keywords=keywords, concepts=concepts)
# Out:
# ## Load list of common codes from csv and filter to Respiratory activity only
# High level codes: 9
# Detailed codes: 30

# %% [markdown]
# ### Additional manual filtering
# Customised for each topic after inspecting the results of the previous step

# %%
######################### customise ################################
# remove irrelevant items by filtering on CTV3 concepts/descriptions
concepts1 = ["Drug"]
keywords1 = []
concepts2 = [] 
keywords2 = []
####################################################################

highlevel = filter_codelists(highlevel, concepts=concepts1, keywords=keywords1, codelist_type="High level",  eventcount=True)
detailed = filter_codelists(detailed, concepts=concepts2, keywords=keywords2, codelist_type="Detailed",  eventcount=True) 


######################### customise ################################
# replace all detailed concepts with single topic
highlevel["concept_desc"] = "Respiratory"
detailed["concept_desc"] = "Respiratory"
####################################################################
# Out:
# High level codes: 9
# Event count: 1.37 million
# Detailed codes: 30
# Event count: 22.49 million

# %% [markdown]
# # Plotting decile charts
# ### Charts highlight the median practice for the rate of each code occurrence each month, along with the rates at each decile (10-90%)
# - NB Practice denominators (list size) and patient registrations only include current patients

# %% [markdown]
# # High level codes <a class="anchor" id="highlevel"></a>
# Jump to [detailed codes](#detailed)

# %%
N = min(len(highlevel), 25) # number of charts to plot
plotting_all(highlevel, codes, N, threshold, end_date, dbconn, True)
# Out:
# # ---
#  # Category: Respiratory
# Total events: 1.37 m
# ## Contents:
#     first_digits                                        Description  \
# 17            17                               Respiratory symptoms
# 46            H3                   Chronic obstructive lung disease
# 89            87  Respiratory procedures (& respiratory resuscit...
# 134           H0                       Acute respiratory infections
# 149           H1             Other upper respiratory tract diseases
# 183           p4                             Respiratory appliances
# 192           H5                  Other respiratory system diseases
# 202           74                        Respiratory tract procedure
# 246            H                               Respiratory disorder
#
#      2020 events (mill)  2020 Patient count (mill)
# 17                 0.92                       0.67
# 46                 0.26                       0.21
# 89                 0.10                       0.09
# 134                0.03                       0.03
# 149                0.03                       0.02
# 183                0.01                       0.01
# 192                0.01                       0.01
# 202                0.01                       0.01
# 246                0.00                       0.00
# ## "17" - Respiratory symptoms
#  ### (Practices included: 2.5k (100.0%); 2020 events: 0.92m); 2020 patients: 668.7k
# Feb median: 3.6 (IDR 11.9), April median: 2.0 (IDR 7.0), September median: 2.4 (IDR 8.7)
# Change in median from 2019: April -8.2% (No change); September -4.1%, (No change); Overall classification: **No change**
# Top 'child' codes represented within parent code above:
#   first_digits  2020 events (thou)           Description
# 0         1731               279.5     No breathlessness
# 1         1711               154.0              No cough
# 2           17               138.5  Respiratory symptoms
# 3         1719                58.3          Chesty cough
# 4         1712                44.3             Dry cough
# ### Trend in top child code: 1731 - No breathlessness
# ## "H3" - Chronic obstructive lung disease
#  ### (Practices included: 2.5k (99.8%); 2020 events: 0.26m); 2020 patients: 205.0k
# Feb median: 1.1 (IDR 2.7), April median: 0.5 (IDR 2.2), September median: 0.7 (IDR 2.1)
# Change in median from 2019: April -49.0% (Small drop); September -35.7%, (Small drop); Overall classification: **Sustained drop**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)  \
# 23          H33               154.2
# 24           H3                54.2
# 25        H3122                26.9
# 26          H34                11.0
# 27          H32                 5.1
#
#                                           Description
# 23                                             Asthma
# 24                   Chronic obstructive lung disease
# 25  Acute exacerbation of chronic obstructive airw...
# 26                                     Bronchiectasis
# 27                                          Emphysema
# ### Trend in top child code: H33 - Asthma
# ## "87" - Respiratory procedures (& respiratory resuscitation)
#  ### (Practices included: 2.4k (92.5%); 2020 events: 0.1m); 2020 patients: 90.5k
# Feb median: 0.0 (IDR 2.3), April median: 0.0 (IDR 1.0), September median: 0.0 (IDR 1.3)
# Change in median from 2019: April 0% (No change); September 0%, (No change); Overall classification: **No change**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)            Description
# 31         8795                37.9  Asthma control step 2
# 32         8796                31.5  Asthma control step 3
# 33         8794                16.3  Asthma control step 1
# 34         8797                 4.1  Asthma control step 4
# 35         8793                 3.5  Asthma control step 0
# ### Trend in top child code: 8795 - Asthma control step 2
# ## "H0" - Acute respiratory infections
#  ### (Practices included: 2.5k (98.8%); 2020 events: 0.03m); 2020 patients: 31.2k
# Feb median: 0.2 (IDR 0.8), April median: 0.0 (IDR 0.2), September median: 0.0 (IDR 0.3)
# Change in median from 2019: April -100.0% (Large drop); September -100.0%, (Large drop); Overall classification: **Sustained drop**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)                   Description
# 37         H035                 5.5   Acute bacterial tonsillitis
# 38         H036                 3.5       Acute viral tonsillitis
# 39           H0                 2.6  Acute respiratory infections
# 40         H03z                 2.6         Acute tonsillitis NOS
# 41         H040                 2.2              Acute laryngitis
# ### Trend in top child code: H035 - Acute bacterial tonsillitis
# ## "H1" - Other upper respiratory tract diseases
#  ### (Practices included: 2.5k (98.9%); 2020 events: 0.03m); 2020 patients: 24.6k
# Feb median: 0.2 (IDR 0.5), April median: 0.0 (IDR 0.2), September median: 0.1 (IDR 0.3)
# Change in median from 2019: April -100.0% (Large drop); September -55.2%, (Small drop); Overall classification: **Sustained drop**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)            Description
# 48          H13                 8.1      Chronic sinusitis
# 49          H11                 6.0            Nasal polyp
# 50         H17z                 2.0  Allergic rhinitis NOS
# 51          H15                 2.0  Peritonsillar abscess
# 52        H14y0                 1.6     Tonsillar calculus
# ### Trend in top child code: H13 - Chronic sinusitis
# ## "p4" - Respiratory appliances
#  ### (Practices included: 1.0k (38.8%); 2020 events: 0.01m); 2020 patients: 10.0k
# Feb median: 0.0 (IDR 0.1), April median: 0.0 (IDR 0.0), September median: 0.0 (IDR 0.0)
# Change in median from 2019: April 0% (No change); September 0%, (No change); Overall classification: **No change**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou) Description
# 53          p44                12.0     Inhaler
# ### Trend in top child code: p44 - Inhaler
# ## "H5" - Other respiratory system diseases
#  ### (Practices included: 2.4k (96.1%); 2020 events: 0.01m); 2020 patients: 11.2k
# Feb median: 0.0 (IDR 0.2), April median: 0.0 (IDR 0.1), September median: 0.0 (IDR 0.2)
# Change in median from 2019: April 0% (No change); September 0%, (No change); Overall classification: **No change**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)   Description
# 54          H51                 3.3      Pleurisy
# 55          H52                 2.8  Pneumothorax
# ### Trend in top child code: H51 - Pleurisy
# ## "74" - Respiratory tract procedure
#  ### (Practices included: 2.4k (94.1%); 2020 events: 0.01m); 2020 patients: 8.6k
# Feb median: 0.0 (IDR 0.2), April median: 0.0 (IDR 0.1), September median: 0.0 (IDR 0.2)
# Change in median from 2019: April 0% (No change); September 0%, (No change); Overall classification: **No change**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)        Description
# 56        74512                 1.2  Lobectomy of lung
# ### Trend in top child code: 74512 - Lobectomy of lung
# ## "H" - Respiratory disorder
#  ### (Practices included: 2.5k (99.9%); 2020 events: 0.0m); 2020 patients: 4.7k
# Feb median: 1.8 (IDR 3.5), April median: 0.7 (IDR 2.4), September median: 1.0 (IDR 2.5)
# Change in median from 2019: April -53.3% (Small drop); September -36.9%, (Small drop); Overall classification: **Sustained drop**

# %% [markdown]
# # Detailed codes <a id="detailed"></a>
# Jump back to [high-level codes](#highlevel)

# %%
N = min(len(detailed), 75) # number of charts to plot
pd.set_option('display.max_rows', 100) # display full contents table
plotting_all(detailed, codes, N, threshold, end_date, dbconn, False)
# Out:
# # ---
#  # Category: Respiratory
# Total events: 22.49 m
# ## Contents:
#     first_digits                                        Description  \
# 7          Y22b6  Provision of advice, assessment or treatment l...
# 50         Y20d2  SARS-CoV-2 (severe acute respiratory syndrome ...
# 61           663  Respiratory disease monitoring (& [asthma] or ...
# 93         Y228a  High risk category for developing complication...
# 107        XaIeq                               Asthma annual review
# 150        Y212d  Advice given about severe acute respiratory sy...
# 162        XaQHq                                Asthma control test
# 165        X774f                                   Respiratory rate
# 174        Y211b  Telephone consultation for suspected severe ac...
# 211        Y228b  Moderate risk category for developing complica...
# 213        XaINa               Asthma never causes daytime symptoms
# 223        XaINh        Number of asthma exacerbations in past year
# 234        XaY2V                 Asthma never causes night symptoms
# 276        Y20cf  Suspected coronavirus disease 19 caused by sev...
# 272        XaIet  Chronic obstructive pulmonary disease annual r...
# 284        Xa1sb            Viral upper respiratory tract infection
# 313        XaIPs                       Good compliance with inhaler
# 320          9OJ    Asthma administration: [monitoring] or [clinic]
# 341        XaRFy  Chronic obstructive pulmonary disease assessme...
# 345        XaIfK                           Asthma medication review
# 383        XaYZB                 Asthma self-management plan review
# 401        XaYb8                 Asthma self-management plan agreed
# 418        XaK8U          Number of COPD exacerbations in past year
# 423        XaINb  Asthma causes daytime symptoms 1 to 2 times pe...
# 422        X1004               Infection of lower respiratory tract
# 478        XaIu5                         Asthma monitoring by nurse
# 475        XaINc  Asthma causes daytime symptoms 1 to 2 times pe...
# 466          H33                                             Asthma
# 487        Y212c  Advice given about severe acute respiratory sy...
# 493        Y0024                                     Asthma Control
#
#      2020 events (mill)  2020 Patient count (mill)
# 7                  6.78                       3.12
# 50                 3.10                       2.10
# 61                 2.46                       0.92
# 93                 1.26                       1.05
# 107                1.08                       0.81
# 150                0.69                       0.26
# 162                0.64                       0.35
# 165                0.62                       0.52
# 174                0.58                       0.43
# 211                0.46                       0.43
# 213                0.45                       0.40
# 223                0.41                       0.36
# 234                0.38                       0.34
# 276                0.31                       0.25
# 272                0.31                       0.25
# 284                0.29                       0.27
# 313                0.25                       0.23
# 320                0.25                       0.20
# 341                0.23                       0.11
# 345                0.22                       0.20
# 383                0.20                       0.17
# 401                0.19                       0.17
# 418                0.18                       0.16
# 423                0.18                       0.16
# 422                0.18                       0.16
# 478                0.16                       0.15
# 475                0.16                       0.15
# 466                0.16                       0.13
# 487                0.16                       0.13
# 493                0.15                       0.14
# ## "Y22b6" - Provision of advice, assessment or treatment limited due to coronavirus disease 19 caused by severe acute respiratory syndrome coronavirus 2 pandemic (situation)
#  ### (Practices included: 2.4k (95.9%); 2020 events: 6.78m); 2020 patients: 3.12m
# Feb median: 0.0 (IDR 0.0), April median: 2.1 (IDR 123.3), September median: 7.1 (IDR 134.4)
# Change in median from 2019: April 100% (Increase); September 100%, (Increase); Overall classification: **Increase**
# ## "Y20d2" - SARS-CoV-2 (severe acute respiratory syndrome coronavirus 2) RNA (ribonucleic acid) detection result negative
#  ### (Practices included: 2.5k (99.8%); 2020 events: 3.1m); 2020 patients: 2.1m
# Feb median: 0.0 (IDR 0.2), April median: 1.3 (IDR 2.1), September median: 44.1 (IDR 37.8)
# Change in median from 2019: April 100% (Increase); September 100%, (Increase); Overall classification: **Increase**
# ## "663" - Respiratory disease monitoring (& [asthma] or [chronic])
#  ### (Practices included: 2.5k (99.8%); 2020 events: 2.46m); 2020 patients: 916.4k
# Feb median: 13.7 (IDR 22.0), April median: 5.8 (IDR 21.7), September median: 6.8 (IDR 15.5)
# Change in median from 2019: April -40.1% (Small drop); September -41.2%, (Small drop); Overall classification: **Sustained drop**
# Top 'child' codes represented within parent code above:
#   first_digits  2020 events (thou)                           Description
# 0         663Q               598.6        Asthma not limiting activities
# 1         663H               371.5              Inhaler technique - good
# 2         663O               290.0           Asthma not disturbing sleep
# 3        663g1               159.0  Using inhaled steroids - normal dose
# 4         663U               132.8          Asthma management plan given
# ## "Y228a" - High risk category for developing complication from coronavirus disease 19 caused by severe acute respiratory syndrome coronavirus 2 infection (finding)
#  ### (Practices included: 2.5k (99.9%); 2020 events: 1.26m); 2020 patients: 1.05m
# Feb median: 0.0 (IDR 0.0), April median: 21.8 (IDR 34.0), September median: 0.2 (IDR 0.5)
# Change in median from 2019: April 100% (Increase); September 100%, (Increase); Overall classification: **Increase**
# ## "XaIeq" - Asthma annual review
#  ### (Practices included: 2.5k (99.9%); 2020 events: 1.08m); 2020 patients: 811.8k
# Feb median: 5.1 (IDR 7.8), April median: 2.8 (IDR 10.6), September median: 3.8 (IDR 8.4)
# Change in median from 2019: April -29.3% (Small drop); September -11.8%, (No change); Overall classification: **Recovered**
# ## "Y212d" - Advice given about severe acute respiratory syndrome coronavirus 2 infection (situation)
#  ### (Practices included: 2.1k (80.8%); 2020 events: 0.69m); 2020 patients: 260.0k
# Feb median: 0.0 (IDR 0.0), April median: 0.8 (IDR 10.9), September median: 0.0 (IDR 2.7)
# Change in median from 2019: April 100% (Increase); September 0%, (No change); Overall classification: **Increase**
# ## "XaQHq" - Asthma control test
#  ### (Practices included: 2.5k (98.7%); 2020 events: 0.64m); 2020 patients: 354.2k
# Feb median: 0.8 (IDR 7.4), April median: 0.4 (IDR 7.8), September median: 2.8 (IDR 10.2)
# Change in median from 2019: April 98.0% (Increase); September 445.5%, (Increase); Overall classification: **Increase**
# ## "X774f" - Respiratory rate
#  ### (Practices included: 2.5k (98.9%); 2020 events: 0.62m); 2020 patients: 516.1k
# Feb median: 1.6 (IDR 16.5), April median: 0.2 (IDR 1.9), September median: 0.4 (IDR 4.5)
# Change in median from 2019: April -67.7% (Large drop); September -54.4%, (Small drop); Overall classification: **Sustained drop**
# ## "Y211b" - Telephone consultation for suspected severe acute respiratory syndrome coronavirus 2 (procedure)
#  ### (Practices included: 2.4k (96.1%); 2020 events: 0.58m); 2020 patients: 425.0k
# Feb median: 0.0 (IDR 0.0), April median: 2.2 (IDR 21.0), September median: 0.3 (IDR 4.3)
# Change in median from 2019: April 100% (Increase); September 100%, (Increase); Overall classification: **Increase**
# ## "Y228b" - Moderate risk category for developing complication from coronavirus disease 19 caused by severe acute respiratory syndrome coronavirus 2 infection (finding)
#  ### (Practices included: 2.4k (96.0%); 2020 events: 0.46m); 2020 patients: 429.5k
# Feb median: 0.0 (IDR 0.0), April median: 2.4 (IDR 23.4), September median: 0.0 (IDR 0.4)
# Change in median from 2019: April 100% (Increase); September 0%, (No change); Overall classification: **Increase**
# ## "XaINa" - Asthma never causes daytime symptoms
#  ### (Practices included: 2.5k (99.7%); 2020 events: 0.45m); 2020 patients: 399.3k
# Feb median: 2.2 (IDR 4.1), April median: 1.0 (IDR 4.8), September median: 1.1 (IDR 2.9)
# Change in median from 2019: April -33.4% (Small drop); September -40.5%, (Small drop); Overall classification: **Sustained drop**
# ## "XaINh" - Number of asthma exacerbations in past year
#  ### (Practices included: 2.5k (98.7%); 2020 events: 0.41m); 2020 patients: 362.4k
# Feb median: 0.7 (IDR 4.2), April median: 0.4 (IDR 4.4), September median: 2.0 (IDR 5.8)
# Change in median from 2019: April 58.0% (Increase); September 371.1%, (Increase); Overall classification: **Increase**
# ## "XaY2V" - Asthma never causes night symptoms
#  ### (Practices included: 2.5k (98.2%); 2020 events: 0.38m); 2020 patients: 340.9k
# Feb median: 1.1 (IDR 5.1), April median: 0.3 (IDR 4.8), September median: 0.7 (IDR 3.7)
# Change in median from 2019: April -25.4% (Small drop); September -24.0%, (Small drop); Overall classification: **Sustained drop**
# ## "Y20cf" - Suspected coronavirus disease 19 caused by severe acute respiratory syndrome coronavirus 2 (situation)
#  ### (Practices included: 2.5k (99.6%); 2020 events: 0.31m); 2020 patients: 245.2k
# Feb median: 0.0 (IDR 0.1), April median: 3.7 (IDR 6.8), September median: 1.7 (IDR 2.8)
# Change in median from 2019: April 100% (Increase); September 100%, (Increase); Overall classification: **Increase**
# ## "XaIet" - Chronic obstructive pulmonary disease annual review
#  ### (Practices included: 2.5k (99.4%); 2020 events: 0.31m); 2020 patients: 245.2k
# Feb median: 1.7 (IDR 3.8), April median: 0.3 (IDR 2.7), September median: 0.8 (IDR 3.0)
# Change in median from 2019: April -66.7% (Large drop); September -36.1%, (Small drop); Overall classification: **Sustained drop**
# ## "Xa1sb" - Viral upper respiratory tract infection
#  ### (Practices included: 2.5k (99.8%); 2020 events: 0.29m); 2020 patients: 273.7k
# Feb median: 3.3 (IDR 6.9), April median: 0.1 (IDR 0.6), September median: 0.4 (IDR 1.5)
# Change in median from 2019: April -94.9% (Large drop); September -80.4%, (Large drop); Overall classification: **Sustained drop**
# ## "XaIPs" - Good compliance with inhaler
#  ### (Practices included: 2.3k (88.7%); 2020 events: 0.25m); 2020 patients: 227.0k
# Feb median: 0.3 (IDR 4.3), April median: 0.1 (IDR 3.3), September median: 0.5 (IDR 3.5)
# Change in median from 2019: April 100.0% (Increase); September 273.6%, (Increase); Overall classification: **Increase**
# ## "9OJ" - Asthma administration: [monitoring] or [clinic]
#  ### (Practices included: 2.5k (97.8%); 2020 events: 0.25m); 2020 patients: 201.3k
# Feb median: 0.1 (IDR 5.9), April median: 0.0 (IDR 0.3), September median: 0.0 (IDR 1.5)
# Change in median from 2019: April -100.0% (Large drop); September -100.0%, (Large drop); Overall classification: **Sustained drop**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)                              Description
# 36         9OJ4               129.4      Asthma monitoring call first letter
# 37         9OJ5                56.0     Asthma monitoring call second letter
# 38         9OJ8                37.8  Asthma monitoring call telephone invite
# 39         9OJ6                15.3      Asthma monitoring call third letter
# 40         9OJ7                10.1     Asthma monitoring call verbal invite
# ## "XaRFy" - Chronic obstructive pulmonary disease assessment test
#  ### (Practices included: 2.2k (87.8%); 2020 events: 0.23m); 2020 patients: 109.1k
# Feb median: 0.5 (IDR 4.6), April median: 0.0 (IDR 2.1), September median: 0.2 (IDR 3.5)
# Change in median from 2019: April -100.0% (Large drop); September -15.3%, (Small drop); Overall classification: **Sustained drop**
# ## "XaIfK" - Asthma medication review
#  ### (Practices included: 2.5k (99.0%); 2020 events: 0.22m); 2020 patients: 201.0k
# Feb median: 0.4 (IDR 3.5), April median: 0.1 (IDR 2.7), September median: 0.3 (IDR 2.8)
# Change in median from 2019: April -49.7% (Small drop); September -30.1%, (Small drop); Overall classification: **Sustained drop**
# ## "XaYZB" - Asthma self-management plan review
#  ### (Practices included: 2.4k (94.8%); 2020 events: 0.2m); 2020 patients: 174.8k
# Feb median: 0.0 (IDR 1.4), April median: 0.0 (IDR 3.0), September median: 1.2 (IDR 5.0)
# Change in median from 2019: April 0% (No change); September 100%, (Increase); Overall classification: **Increase**
# ## "XaYb8" - Asthma self-management plan agreed
#  ### (Practices included: 2.3k (92.2%); 2020 events: 0.19m); 2020 patients: 171.1k
# Feb median: 0.1 (IDR 3.5), April median: 0.0 (IDR 2.5), September median: 0.0 (IDR 1.2)
# Change in median from 2019: April -100.0% (Large drop); September -100.0%, (Large drop); Overall classification: **Sustained drop**
# ## "XaK8U" - Number of COPD exacerbations in past year
#  ### (Practices included: 2.5k (96.9%); 2020 events: 0.18m); 2020 patients: 155.9k
# Feb median: 0.6 (IDR 2.5), April median: 0.1 (IDR 1.6), September median: 0.5 (IDR 2.4)
# Change in median from 2019: April -76.1% (Large drop); September 8.0%, (No change); Overall classification: **Recovered**
# ## "XaINb" - Asthma causes daytime symptoms 1 to 2 times per month
#  ### (Practices included: 2.5k (99.6%); 2020 events: 0.18m); 2020 patients: 159.4k
# Feb median: 0.7 (IDR 1.8), April median: 0.3 (IDR 1.9), September median: 0.4 (IDR 1.2)
# Change in median from 2019: April -39.2% (Small drop); September -43.1%, (Small drop); Overall classification: **Sustained drop**
# ## "X1004" - Infection of lower respiratory tract
#  ### (Practices included: 2.5k (99.6%); 2020 events: 0.18m); 2020 patients: 161.6k
# Feb median: 1.3 (IDR 3.3), April median: 0.2 (IDR 0.9), September median: 0.3 (IDR 1.1)
# Change in median from 2019: April -77.2% (Large drop); September -61.9%, (Large drop); Overall classification: **Sustained drop**
# ## "XaIu5" - Asthma monitoring by nurse
#  ### (Practices included: 2.4k (93.0%); 2020 events: 0.16m); 2020 patients: 145.5k
# Feb median: 0.1 (IDR 2.9), April median: 0.0 (IDR 2.1), September median: 0.0 (IDR 2.5)
# Change in median from 2019: April -100.0% (Large drop); September -100.0%, (Large drop); Overall classification: **Sustained drop**
# ## "XaINc" - Asthma causes daytime symptoms 1 to 2 times per week
#  ### (Practices included: 2.5k (99.4%); 2020 events: 0.16m); 2020 patients: 148.6k
# Feb median: 0.7 (IDR 1.6), April median: 0.4 (IDR 1.8), September median: 0.4 (IDR 1.3)
# Change in median from 2019: April -17.5% (Small drop); September -24.7%, (Small drop); Overall classification: **Sustained drop**
# ## "H33" - Asthma
#  ### (Practices included: 2.5k (99.8%); 2020 events: 0.16m); 2020 patients: 129.1k
# Feb median: 0.5 (IDR 1.7), April median: 0.3 (IDR 1.5), September median: 0.3 (IDR 1.3)
# Change in median from 2019: April -44.8% (Small drop); September -37.7%, (Small drop); Overall classification: **Sustained drop**
# Top 'child' codes represented within parent code above:
#    first_digits  2020 events (thou)         Description
# 43          H33               154.2              Asthma
# 44         H33z                 2.2  Asthma unspecified
# ## "Y212c" - Advice given about severe acute respiratory syndrome coronavirus 2 by telephone (situation)
#  ### (Practices included: 2.0k (77.6%); 2020 events: 0.16m); 2020 patients: 129.2k
# Feb median: 0.0 (IDR 0.0), April median: 0.4 (IDR 4.1), September median: 0.0 (IDR 0.4)
# Change in median from 2019: April 100% (Increase); September 0%, (No change); Overall classification: **Increase**
# ## "Y0024" - Asthma Control
#  ### (Practices included: 2.0k (79.1%); 2020 events: 0.15m); 2020 patients: 138.0k
# Feb median: 0.0 (IDR 3.0), April median: 0.0 (IDR 2.3), September median: 0.2 (IDR 3.1)
# Change in median from 2019: April 0% (No change); September 100%, (Increase); Overall classification: **Increase**
